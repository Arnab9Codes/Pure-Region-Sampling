# %%
import Classify

# %%
import numpy as np

# %%
n=np.arange(0.0,1.01,0.05)

# %%
for i in range(len(n)):
    
    n[i]=round(n[i],2)
    print('leaf purity: ',n[i])
    pred=Classify.Classify('../Data_tsai/NonSMOTE/cleveland-0_vs_4/cleveland-0_vs_4-5-fold/','cleveland-0_vs_4-5-5tra.dat',\
                         'cleveland-0_vs_4-5-5tst.dat',False,n[i])
    print('-----------------------------------')
# Out:
# leaf purity:  0.0
# without oversampling:  0.9117647058823529
#
# Oversampling on:
#
# ['negative' 'positive']
# [128  11]
# Minority class:  positive
# (116, 14)
# Y shape: (139,)
# with oversampling:  0.9117647058823529
# -----------------------------------
# leaf purity:  0.05
# without oversampling:  0.9117647058823529
#
# Oversampling on:
#
# ['negative' 'positive']
# [128  11]
# Minority class:  positive
# (116, 14)
# Y shape: (139,)
# with oversampling:  0.9117647058823529
# -----------------------------------
# leaf purity:  0.1
# without oversampling:  0.9117647058823529
#
# Oversampling on:
#
# ['negative' 'positive']
# [128  11]
# Minority class:  positive
# (117, 14)
# Y shape: (139,)
# with oversampling:  0.9117647058823529
# -----------------------------------
# leaf purity:  0.15
# without oversampling:  0.9117647058823529
#
# Oversampling on:
#
# ['negative' 'positive']
# [128  11]
# Minority class:  positive
# (117, 14)
# Y shape: (139,)
# ...
