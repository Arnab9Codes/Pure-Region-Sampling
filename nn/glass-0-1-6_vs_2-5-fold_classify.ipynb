# %%
import Classify

# %%
import numpy as np

# %%
n=np.arange(0.0,1.01,0.01)

# %%
for i in range(len(n)):
    
    n[i]=round(n[i],2)
    print('leaf purity: ',n[i])
    pred=Classify.Classify('../Data_tsai/NonSMOTE/glass-0-1-6_vs_2/glass-0-1-6_vs_2-5-fold/','glass-0-1-6_vs_2-5-2tra.dat',\
                         'glass-0-1-6_vs_2-5-2tst.dat',False,n[i])
    print('-----------------------------------')
# Out:
# leaf purity:  0.0
# without oversampling:  0.8974358974358975
#
# Oversampling on:
#
# [' negative' ' positive']
# [140  13]
# Minority class:   positive
# (128, 10)
# Y shape: (153,)
# with oversampling:  0.7692307692307693
# -----------------------------------
# leaf purity:  0.01
# without oversampling:  0.8974358974358975
#
# Oversampling on:
#
# [' negative' ' positive']
# [140  13]
# Minority class:   positive
# (128, 10)
# Y shape: (153,)
# with oversampling:  0.7692307692307693
# -----------------------------------
# leaf purity:  0.02
# without oversampling:  0.8974358974358975
#
# Oversampling on:
#
# [' negative' ' positive']
# [140  13]
# Minority class:   positive
# (128, 10)
# Y shape: (153,)
# with oversampling:  0.7692307692307693
# -----------------------------------
# leaf purity:  0.03
# without oversampling:  0.8974358974358975
#
# Oversampling on:
#
# [' negative' ' positive']
# [140  13]
# Minority class:   positive
# (127, 10)
# Y shape: (153,)
# ...
